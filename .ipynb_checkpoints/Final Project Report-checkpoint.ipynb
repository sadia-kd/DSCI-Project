# %% [markdown]
# ### Final Report (Group #36)

# %%
# Load the packages and set the seed

library(tidyverse)
library(repr)
library(tidymodels)
library(dplyr)
library(GGally)

options(repr.matrix.max.rows = 6)
set.seed(1)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ...

# %% [markdown]
# ### INTRO:

# %%
url <- "https://raw.githubusercontent.com/sadia-kd/DSCI-Project/main/heart.csv"

heart_disease <- read_csv(url) %>%
    mutate(target = as_factor(target)) %>%
    unique()

heart_disease
# Out:
# Parsed with column specification:
# cols(
#   age = col_double(),
#   sex = col_double(),
#   cp = col_double(),
#   trestbps = col_double(),
#   chol = col_double(),
#   fbs = col_double(),
#   restecg = col_double(),
#   thalach = col_double(),
#   exang = col_double(),
#   oldpeak = col_double(),
#   slope = col_double(),
#   ca = col_double(),
#   thal = col_double(),
#   target = col_double()
# )
#     age sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca thal
# 1   52  1   0  125      212  0   1       168     0     1.0     2     2  3
# 2   53  1   0  140      203  1   0       155     1     3.1     0     0  3
# 3   70  1   0  145      174  0   1       125     1     2.6     0     0  3
# ⋮   ⋮   ⋮   ⋮  ⋮        ⋮    ⋮   ⋮       ⋮       ⋮     ⋮       ⋮     ⋮  ⋮
# 300 52  1   0  128      255  0   1       161     1     0.0     2     1  3
# 301 59  1   3  160      273  0   0       125     0     0.0     2     0  2
# ...

# %% [markdown]
# ### Explore The Data

# %%
# spliting the data intro training set 

heart_disease_split <- initial_split(heart_disease, prop = 0.75, strata = target)
heart_disease_train <- training(heart_disease_split)
heart_disease_test <- testing(heart_disease_split)

# %%
# Summarize the DATA 

obs <- nrow(heart_disease_train)

data_count <- heart_disease_train %>%
    group_by(target) %>%
    summarize(count = n(), percentage = n()/obs * 100)

data_count
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   target count percentage
# 1 0      104   45.81498
# 2 1      123   54.18502

# %%
sum(is.na(heart_disease_train))
# Out:
# [1] 0

# %%
summary(heart_disease_train)
# Out:
#       age             sex               cp            trestbps
#  Min.   :29.00   Min.   :0.0000   Min.   :0.0000   Min.   : 94.0
#  1st Qu.:47.00   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:120.0
#  Median :55.00   Median :1.0000   Median :1.0000   Median :130.0
#  Mean   :54.25   Mean   :0.6784   Mean   :0.9163   Mean   :130.9
#  3rd Qu.:61.00   3rd Qu.:1.0000   3rd Qu.:2.0000   3rd Qu.:140.0
#  Max.   :74.00   Max.   :1.0000   Max.   :3.0000   Max.   :200.0
#       chol            fbs            restecg          thalach
#  Min.   :126.0   Min.   :0.0000   Min.   :0.0000   Min.   : 71.0
#  1st Qu.:211.0   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:139.5
#  Median :241.0   Median :0.0000   Median :1.0000   Median :154.0
#  Mean   :249.0   Mean   :0.1498   Mean   :0.5463   Mean   :150.7
#  3rd Qu.:279.5   3rd Qu.:0.0000   3rd Qu.:1.0000   3rd Qu.:167.5
#  Max.   :564.0   Max.   :1.0000   Max.   :2.0000   Max.   :202.0
#      exang           oldpeak          slope            ca
# ...

# %% [markdown]
# ## _Performing the Analsyis_

# %% [markdown]
# # The following block is for visuliazation demo

# %%
# Use k = 3 here for demo
hd_train = heart_disease_train %>%
    select(target,trestbps,chol,thalach,age)
hd_test = heart_disease_test %>%
    select(target,trestbps,chol,thalach,age)

# spec for all cases
hd_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 3) %>%
      set_engine("kknn") %>%
      set_mode("classification")

# case 1: all 4 variables, no 4D visualization
hd_all_recipe <- recipe(target ~. , data = hd_train)

hd_all_fit <- workflow() %>%
      add_recipe(hd_all_recipe) %>%
      add_model(hd_spec) %>%
      fit(data = hd_train)

hd_all_predictions = predict(heart_disease_fit,hd_test) %>%
                         bind_cols(hd_test)

# case 2: combination of 3 variables(4 sub-cases), 3D visualization (not recommanded by testbook)

# case 3: combination of 2 variables(6 sub-cases)
# case 3-1: trestbps vs chol
hd_trch_recipe <- recipe(target ~ trestbps + chol , data = hd_train)

hd_trch_fit <- workflow() %>%
      add_recipe(hd_trch_recipe) %>%
      add_model(hd_spec) %>%
      fit(data = hd_train)

hd_trch_predictions = predict(hd_trch_fit,hd_test) %>%
                         bind_cols(hd_test)
# Out:
#    .pred_class target trestbps chol thalach age
# 1  0           0      160      289  145     55
# 2  1           0      140      185  155     60
# 3  0           0      130      131  115     57
# ⋮  ⋮           ⋮      ⋮        ⋮    ⋮       ⋮
# 73 0           1      150      226  114     66
# 74 1           1      120      178   96     60
# 75 1           1      120      211  115     68

# %%
# create the grid of area/smoothness vals, and arrange in a data frame
tr_grid <- seq(min(hd_train$trestbps), 
                max(hd_train$trestbps), 
                length.out = 100)
ch_grid <- seq(min(hd_train$chol), 
                max(hd_train$chol), 
                length.out = 100)
asgrid <- as_tibble(expand.grid(trestbps = tr_grid, 
                                chol = ch_grid))

# use the fit workflow to make predictions at the grid points
knnPredGrid <- predict(hd_trch_fit, asgrid)

# bind the predictions as a new column with the grid points
prediction_table <- bind_cols(knnPredGrid, asgrid)

# plot:
# 1. the colored scatter of the original data
# 2. the faded colored scatter for the grid points
wkflw_plot <-
  ggplot() +
  geom_point(data = hd_train, 
             mapping = aes(x = trestbps, 
                           y = chol, 
                           color = target), 
             alpha = 0.75) +
  geom_point(data = prediction_table, 
             mapping = aes(x = trestbps, 
                           y = chol, 
                           color = .pred_class), 
             alpha = 0.02, 
             size = 5) +
  labs(color = "Heart Disease", 
       x = "trestbps", 
       y = "chol") +
  scale_color_manual(labels = c("yes", "no"), 
                     values = c("orange2", "steelblue2")) +
  theme(text = element_text(size = 12))

wkflw_plot
# Out:
# plot without title

# %%
# I am thinking group them up for visualization...
# OR, we can make scattor plot with 2 variables but color it with the result using prediction from 4 variables. not sure if it is confusing.
